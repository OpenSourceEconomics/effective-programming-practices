# %% [markdown]
# # Advanced Type Patterns
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Use NewType to create semantically distinct types from the same base type
# - Use Literal to constrain values to a fixed set of options
# - Use Protocol for structural (duck) typing without inheritance
# - Use @overload to express type-dependent return types
# - Apply the "make illegal states unrepresentable" design principle
#
# ## Materials
#
# <iframe
#   src="https://example.com/placeholder"
#   width="640"
#   height="360"
#   frameborder="0"
#   allowfullscreen
# ></iframe>
#
# Download the [slides](software_engineering-type_hints_advanced.pdf).
#
# ## Quiz

# %%
from epp_topics.quiz_utilities import display_quiz

content = {
    "What problem does NewType solve?": {
        "Preventing accidental swapping of semantically different values": True,
        "Making code run faster": False,
        "Creating new classes at runtime": False,
        "CarId and DriverId are both int but type checkers distinguish them": True,
    },
    "When should you use Literal instead of Enum?": {
        "When you want simpler inline syntax for a few string options": True,
        "When you need the full features of Enum like methods": False,
        "When the API should accept string values directly": True,
        "Always prefer Literal over Enum": False,
    },
    "What is the key feature of Protocol?": {
        "Classes don't need to inherit from Protocol to satisfy it": True,
        "It requires explicit inheritance like abstract base classes": False,
        "It captures duck typing: 'if it has the right methods, it works'": True,
        "It's faster than regular classes": False,
    },
    "When would you use @overload?": {
        "When a function's return type depends on the input type": True,
        "When you want to call a function multiple times": False,
        "When different argument types lead to different return types": True,
        "When you need to override a method": False,
    },
}

display_quiz(content)
