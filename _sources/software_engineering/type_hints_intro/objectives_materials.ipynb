# %% [markdown]
# # Why Type Hints?
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Explain the benefits of type hints for documentation, IDE support, and bug prevention
# - Understand that type hints are optional and not enforced at runtime
# - Know when to use type hints and when they are optional
# - Understand the role of type checkers like ty and pyright
#
# ## Materials
#
# <iframe
#   src="https://example.com/placeholder"
#   width="640"
#   height="360"
#   frameborder="0"
#   allowfullscreen
# ></iframe>
#
# Download the [slides](software_engineering-type_hints_intro.pdf).
#
# ## Quiz

# %%
from epp_topics.quiz_utilities import display_quiz

content = {
    "What are the main benefits of type hints?": {
        "They make Python code run faster": False,
        "They serve as always up-to-date documentation": True,
        "They enable better IDE autocomplete and error detection": True,
        "They enforce types at runtime": False,
    },
    "What happens when you pass a wrong type to a type-hinted function?": {
        "Python raises a TypeError at runtime": False,
        "The function refuses to execute": False,
        "Nothing happens at runtime - Python ignores type hints": True,
        "The program crashes immediately": False,
    },
    "When should you use type hints?": {
        "Always for function signatures and class attributes": True,
        "Always for every local variable": False,
        "For public APIs that others will use": True,
        "Only when writing library code": False,
    },
    "What tools can check type hints for errors?": {
        "The Python interpreter itself": False,
        "ty (from Astral)": True,
        "pyright (used by VS Code's Pylance)": True,
        "pytest": False,
    },
}

display_quiz(content)
